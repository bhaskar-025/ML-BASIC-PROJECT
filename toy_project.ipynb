# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaskar-025/ML-BASIC-PROJECT/blob/main/toy_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv("placement.csv")

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#     IQ  CGPA  Placement
# 0  123  7.95          0
# 1  136  7.74          0
# 2  113  9.63          1
# 3   99  9.13          0
# 4  127  8.71          1

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['IQ'],df['CGPA'],c=df['Placement'])

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
X
# Out:
#      IQ  CGPA
# 0   123  7.95
# 1   136  7.74
# 2   113  9.63
# 3    99  9.13
# 4   127  8.71
# ..  ...   ...
# 95   98  8.43
# 96  115  7.78
# 97  132  7.43
# 98   99  7.88
# 99   92  8.05
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: Placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_tets=train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#      IQ  CGPA
# 60   98  6.44
# 18   87  8.56
# 38  126  6.60
# 29  117  8.36
# 6   105  8.02
# ..  ...   ...
# 91  128  7.27
# 93   94  6.98
# 7   123  9.65
# 8   142  8.11
# 88  113  9.79
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
Y_tets
# Out:
# 77    0
# 10    0
# 3     0
# 72    0
# 92    0
# 94    0
# 64    0
# 26    0
# 74    1
# 41    0
# Name: Placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_tets,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,Y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %%
import pandas as pd

while True:
    iq = float(input("Enter IQ: "))
    cgpa = float(input("Enter CGPA: "))

    # ✅ DataFrame use karo (list mat banao)
    new_data = pd.DataFrame({
        "IQ": [iq],
        "CGPA": [cgpa]
    })

    new_data_scaled = scaler.transform(new_data)

    result = clf.predict(new_data_scaled)[0]

    if result == 1:
        print("tension mat le tu placement ho jayega")
    else:
        print("padhai start kar bhai  placement nhi hogi")

    cont = input("Check another? (y/n): ")
    if cont.lower() != 'y':
        break
# Out:
# Enter IQ: 140
# Enter CGPA: 9.01
# tension mat le tu placement ho jayega
# Check another? (y/n): n
